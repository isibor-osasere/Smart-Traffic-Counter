# %% [markdown]
# # Problem Statement
# Monitoring and managing vehicle flow in real-time is critical for optimizing traffic management, ensuring road safety, and enhancing infrastructure planning. However, traditional methods rely on costly hardware installations (e.g., loop detectors, cameras with fixed thresholds), which can be inefficient and fail to adapt to dynamic environments.
#
# ### Practical Application
# - **Smart Traffic Management System**:
# This vehicle counter project provides an AI-powered solution to count and classify vehicles (e.g., cars, buses, trucks) in real-time using video feeds. It can be deployed for:
#
# - **Traffic Flow Analysis:** Monitor and analyze vehicle volume on highways or intersections to reduce congestion.
# - **Toll Booth Automation:** Count and classify vehicles for automated toll collection systems.
# - **Accident Detection:** Track abnormal vehicle behavior (e.g., sudden stops) for emergency alerts.
# - **Urban Planning:** Use traffic data to design better road networks and optimize signal timings.
#
#
# By leveraging AI-based detection and tracking, this system offers a scalable and cost-effective alternative to traditional traffic monitoring methods.

# %% [markdown]
# ### YOLOv8 vehicle counter

# %%
from ultralytics import YOLO
import cv2, time

def run_yolov8_tracking_with_counter(video_source, model_path):
    """
    Run vehicle detection, tracking, and counting using YOLOv8 with class names.
    Args:
        video_source: Path to the video file or webcam index (e.g., 0 for default webcam).
        model_path: Path to YOLOv8 model (e.g., "yolov8n.pt").
    """
    # Load YOLOv8 model
    model = YOLO(model_path)

    # Open the video source
    cap = cv2.VideoCapture(video_source)
    if not cap.isOpened():
        print('Error: Unable to open video source.')
        return

    # Vehicle counters and helper variables
    entered_vehicle_ids = []
    exited_vehicle_ids = []

    # Map of vehicle class IDs to names
    class_names = model.names
    vehicle_class_ids = [1, 2, 3, 5, 7]  # IDs for bicycle, car, motorcycle, bus, truck
    vehicle_entry_count = {class_names[cls]: 0 for cls in vehicle_class_ids}
    vehicle_exit_count = {class_names[cls]: 0 for cls in vehicle_class_ids}

    # Entry and exit lines
    entry_line = {'x1': 160, 'y1': 558, 'x2': 708, 'y2': 558}
    exit_line = {'x1': 1155, 'y1': 558, 'x2': 1718, 'y2': 558}
    offset = 20

    while True:
        ret, frame = cap.read()
        if not ret:
            break  # Exit the loop if no more frames

        start_time = time.time()  # Start timer for FPS calculation

        # Perform detection and tracking
        results = model.track(frame, persist=True, tracker="bytetrack.yaml")  # Use built-in ByteTrack tracker

        # Ensure results contain boxes
        if results and results[0].boxes is not None:
            for box in results[0].boxes:
                # Extract bounding box coordinates, class ID, confidence, and track ID
                x1, y1, x2, y2 = map(int, box.xyxy.cpu().numpy().flatten())  # Bounding box coordinates
                cls = int(box.cls.cpu().numpy().item())  # Class ID
                conf = float(box.conf.cpu().numpy().item())  # Confidence score
                track_id = int(box.id.cpu().numpy().item()) if box.id is not None else None  # Track ID (if available)

                # Get the class name
                class_name = class_names[cls]

                # Calculate the center of the bounding box
                center_x, center_y = (x1 + x2) // 2, (y1 + y2) // 2

                # Draw bounding box and label
                color = (0, 255, 0)  # Green color for vehicles
                cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
                #label = f"ID: {track_id}, Class: {class_name}, Conf: {conf:.2f}"
                label = f"{class_name}"
                cv2.putText(frame, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)

                # Count vehicles crossing entry line
                if entry_line['x1'] <= center_x <= entry_line['x2'] and entry_line['y1'] <= center_y <= entry_line['y1'] + offset:
                    if track_id not in entered_vehicle_ids and cls in vehicle_class_ids:
                        vehicle_entry_count[class_name] += 1
                        entered_vehicle_ids.append(track_id)

                # Count vehicles crossing exit line
                if exit_line['x1'] <= center_x <= exit_line['x2'] and exit_line['y1'] - offset <= center_y <= exit_line['y1']:
                    if track_id not in exited_vehicle_ids and cls in vehicle_class_ids:
                        vehicle_exit_count[class_name] += 1
                        exited_vehicle_ids.append(track_id)

        # Draw overlays for entry and exit counters
        y_pos = 100
        cv2.putText(frame, "EXIT", (10, y_pos), cv2.FONT_HERSHEY_SIMPLEX, 1.2, (255, 255, 250), 3)
        for idx, (cls_name, count) in enumerate(vehicle_entry_count.items()):
            y_pos = 150 + idx * 30
            cv2.putText(frame, f"{cls_name}: {count}", (10, y_pos), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255, 255, 255), 2)
        
        y_pos = 100
        cv2.putText(frame, "ENTRY", (1710, y_pos), cv2.FONT_HERSHEY_SIMPLEX, 1.2, (255, 255, 250), 3)
        for idx, (cls_name, count) in enumerate(vehicle_exit_count.items()):
            y_pos = 150 + idx * 30
            cv2.putText(frame, f"{cls_name}: {count}", (1710, y_pos), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255, 255, 255), 2)

        # Draw the counting lines
        cv2.line(frame, (entry_line['x1'], entry_line['y1']), (entry_line['x2'], entry_line['y2']), (0, 127, 255), 3)
        cv2.line(frame, (exit_line['x1'], exit_line['y1']), (exit_line['x2'], exit_line['y2']), (0, 127, 255), 3)

        # Display FPS
        fps = 1 / (time.time() - start_time)
        cv2.putText(frame, f"FPS: {fps:.2f}", (20, 52), cv2.FONT_HERSHEY_PLAIN, 2, (0, 255, 0), 2)

        # Show the frame
        cv2.imshow('YOLOv8 Vehicle Tracking', cv2.resize(frame, (1280, 720)))
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break  # Exit when 'q' is pressed

    # Release resources
    cap.release()
    cv2.destroyAllWindows()

    # Print final counts
    print("Vehicle Entry Counts:", vehicle_entry_count)
    print("Vehicle Exit Counts:", vehicle_exit_count)

# %%
run_yolov8_tracking_with_counter('videos/highway.mp4', 'model/yolov8s.pt')
# Out:
# 0: 384x640 3 cars, 879.8ms
# Speed: 7.0ms preprocess, 879.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 595.4ms
# Speed: 11.0ms preprocess, 595.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 498.3ms
# Speed: 6.0ms preprocess, 498.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 473.7ms
# Speed: 11.0ms preprocess, 473.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 490.7ms
# Speed: 7.0ms preprocess, 490.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 466.8ms
# Speed: 11.0ms preprocess, 466.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 402.4ms
# Speed: 7.0ms preprocess, 402.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 429.4ms
# Speed: 7.0ms preprocess, 429.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 486.6ms
# Speed: 6.0ms preprocess, 486.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 431.4ms
# Speed: 9.0ms preprocess, 431.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 434.8ms
# Speed: 6.0ms preprocess, 434.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 433.9ms
# Speed: 7.0ms preprocess, 433.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 454.0ms
# Speed: 7.0ms preprocess, 454.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 466.7ms
# Speed: 8.0ms preprocess, 466.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 470.8ms
# Speed: 8.4ms preprocess, 470.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 446.0ms
# Speed: 7.0ms preprocess, 446.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 459.3ms
# Speed: 7.0ms preprocess, 459.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 454.7ms
# Speed: 8.0ms preprocess, 454.7ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 492.0ms
# Speed: 7.0ms preprocess, 492.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 474.3ms
# Speed: 8.0ms preprocess, 474.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 482.7ms
# Speed: 7.0ms preprocess, 482.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 455.3ms
# Speed: 7.0ms preprocess, 455.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 476.2ms
# Speed: 9.0ms preprocess, 476.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 465.4ms
# Speed: 8.0ms preprocess, 465.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 452.3ms
# Speed: 7.0ms preprocess, 452.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 456.3ms
# Speed: 6.0ms preprocess, 456.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 473.7ms
# Speed: 7.0ms preprocess, 473.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 470.5ms
# Speed: 8.0ms preprocess, 470.5ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 499.2ms
# Speed: 8.0ms preprocess, 499.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 466.3ms
# Speed: 9.0ms preprocess, 466.3ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 465.4ms
# Speed: 6.9ms preprocess, 465.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 461.8ms
# Speed: 7.0ms preprocess, 461.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 450.8ms
# Speed: 10.0ms preprocess, 450.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 462.0ms
# Speed: 8.0ms preprocess, 462.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 448.0ms
# Speed: 5.6ms preprocess, 448.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 463.5ms
# Speed: 6.2ms preprocess, 463.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 462.3ms
# Speed: 11.0ms preprocess, 462.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 449.5ms
# Speed: 7.0ms preprocess, 449.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 442.8ms
# Speed: 6.0ms preprocess, 442.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 452.7ms
# Speed: 9.0ms preprocess, 452.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 437.9ms
# Speed: 8.0ms preprocess, 437.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 425.8ms
# Speed: 8.0ms preprocess, 425.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 423.9ms
# Speed: 8.0ms preprocess, 423.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 454.4ms
# Speed: 6.0ms preprocess, 454.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 453.3ms
# Speed: 8.0ms preprocess, 453.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 453.7ms
# Speed: 6.0ms preprocess, 453.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 431.6ms
# Speed: 8.5ms preprocess, 431.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 462.7ms
# Speed: 10.0ms preprocess, 462.7ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 464.4ms
# Speed: 6.9ms preprocess, 464.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 453.8ms
# Speed: 7.0ms preprocess, 453.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 434.8ms
# Speed: 10.0ms preprocess, 434.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 444.9ms
# Speed: 7.0ms preprocess, 444.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 433.8ms
# Speed: 6.0ms preprocess, 433.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 458.5ms
# Speed: 5.8ms preprocess, 458.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 472.5ms
# Speed: 10.0ms preprocess, 472.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 455.8ms
# Speed: 8.0ms preprocess, 455.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 446.5ms
# Speed: 6.0ms preprocess, 446.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 470.5ms
# Speed: 10.4ms preprocess, 470.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 449.5ms
# Speed: 9.0ms preprocess, 449.5ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 468.8ms
# Speed: 7.1ms preprocess, 468.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 440.8ms
# Speed: 7.0ms preprocess, 440.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 445.3ms
# Speed: 7.0ms preprocess, 445.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 459.3ms
# Speed: 8.0ms preprocess, 459.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 456.8ms
# Speed: 6.0ms preprocess, 456.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 447.3ms
# Speed: 6.0ms preprocess, 447.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 444.4ms
# Speed: 8.5ms preprocess, 444.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 445.3ms
# Speed: 11.0ms preprocess, 445.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 466.0ms
# Speed: 6.0ms preprocess, 466.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 443.4ms
# Speed: 8.0ms preprocess, 443.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 446.1ms
# Speed: 7.0ms preprocess, 446.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 459.6ms
# Speed: 6.0ms preprocess, 459.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 445.3ms
# Speed: 9.0ms preprocess, 445.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 446.3ms
# Speed: 8.0ms preprocess, 446.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 443.8ms
# Speed: 8.0ms preprocess, 443.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 444.6ms
# Speed: 5.9ms preprocess, 444.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 445.6ms
# Speed: 8.0ms preprocess, 445.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 449.1ms
# Speed: 6.0ms preprocess, 449.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 445.4ms
# Speed: 6.7ms preprocess, 445.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 443.8ms
# Speed: 8.0ms preprocess, 443.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 445.0ms
# Speed: 10.0ms preprocess, 445.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 441.3ms
# Speed: 7.0ms preprocess, 441.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 433.9ms
# Speed: 7.0ms preprocess, 433.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 451.8ms
# Speed: 8.0ms preprocess, 451.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 440.0ms
# Speed: 7.0ms preprocess, 440.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 457.1ms
# Speed: 6.5ms preprocess, 457.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 456.9ms
# Speed: 9.0ms preprocess, 456.9ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 450.8ms
# Speed: 8.5ms preprocess, 450.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 439.7ms
# Speed: 6.0ms preprocess, 439.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 452.2ms
# Speed: 6.3ms preprocess, 452.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 454.0ms
# Speed: 6.0ms preprocess, 454.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 train, 1 truck, 452.2ms
# Speed: 7.0ms preprocess, 452.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 446.8ms
# Speed: 7.0ms preprocess, 446.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 427.1ms
# Speed: 8.0ms preprocess, 427.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 456.8ms
# Speed: 6.0ms preprocess, 456.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 457.0ms
# Speed: 6.0ms preprocess, 457.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 430.8ms
# Speed: 6.0ms preprocess, 430.8ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 423.9ms
# Speed: 9.0ms preprocess, 423.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 466.1ms
# Speed: 8.0ms preprocess, 466.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 454.4ms
# Speed: 6.0ms preprocess, 454.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 445.3ms
# Speed: 8.5ms preprocess, 445.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 481.2ms
# Speed: 5.5ms preprocess, 481.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 469.2ms
# Speed: 7.0ms preprocess, 469.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 459.2ms
# Speed: 6.0ms preprocess, 459.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 439.3ms
# Speed: 7.0ms preprocess, 439.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 434.9ms
# Speed: 10.0ms preprocess, 434.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 2 trucks, 468.8ms
# Speed: 8.0ms preprocess, 468.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 1 truck, 449.2ms
# Speed: 6.0ms preprocess, 449.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 1 truck, 474.3ms
# Speed: 8.0ms preprocess, 474.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 1 truck, 456.4ms
# Speed: 7.5ms preprocess, 456.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 2 trucks, 464.6ms
# Speed: 6.0ms preprocess, 464.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 447.6ms
# Speed: 5.0ms preprocess, 447.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 443.8ms
# Speed: 7.0ms preprocess, 443.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 1 truck, 461.8ms
# Speed: 6.0ms preprocess, 461.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 453.9ms
# Speed: 6.0ms preprocess, 453.9ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 1 train, 2 trucks, 446.4ms
# Speed: 8.0ms preprocess, 446.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 1 train, 1 truck, 452.2ms
# Speed: 7.0ms preprocess, 452.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 2 trucks, 437.8ms
# Speed: 9.0ms preprocess, 437.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 1 truck, 462.1ms
# Speed: 6.0ms preprocess, 462.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 2 trucks, 450.3ms
# Speed: 6.0ms preprocess, 450.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 1 truck, 437.7ms
# Speed: 9.0ms preprocess, 437.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 1 truck, 458.0ms
# Speed: 6.0ms preprocess, 458.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 2 trucks, 476.9ms
# Speed: 9.0ms preprocess, 476.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 451.9ms
# Speed: 7.8ms preprocess, 451.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 2 trucks, 450.7ms
# Speed: 6.0ms preprocess, 450.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 2 trucks, 462.9ms
# Speed: 6.0ms preprocess, 462.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 2 trucks, 458.6ms
# Speed: 8.0ms preprocess, 458.6ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 473.1ms
# Speed: 8.0ms preprocess, 473.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 438.8ms
# Speed: 5.0ms preprocess, 438.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 474.2ms
# Speed: 6.0ms preprocess, 474.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 460.4ms
# Speed: 8.0ms preprocess, 460.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 452.9ms
# Speed: 6.0ms preprocess, 452.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 453.5ms
# Speed: 7.0ms preprocess, 453.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 2 trucks, 447.9ms
# Speed: 7.0ms preprocess, 447.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 2 trucks, 440.2ms
# Speed: 8.0ms preprocess, 440.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 2 trucks, 426.9ms
# Speed: 10.0ms preprocess, 426.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 2 trucks, 444.7ms
# Speed: 7.0ms preprocess, 444.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 2 trucks, 448.8ms
# Speed: 7.5ms preprocess, 448.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 435.2ms
# Speed: 6.0ms preprocess, 435.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 448.3ms
# Speed: 7.0ms preprocess, 448.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 439.6ms
# Speed: 5.0ms preprocess, 439.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 460.6ms
# Speed: 6.0ms preprocess, 460.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 430.0ms
# Speed: 7.0ms preprocess, 430.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 447.1ms
# Speed: 6.0ms preprocess, 447.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 468.7ms
# Speed: 8.0ms preprocess, 468.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 450.1ms
# Speed: 8.0ms preprocess, 450.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 452.8ms
# Speed: 7.0ms preprocess, 452.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 452.3ms
# Speed: 8.0ms preprocess, 452.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 459.6ms
# Speed: 9.0ms preprocess, 459.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 452.3ms
# Speed: 6.0ms preprocess, 452.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 444.0ms
# Speed: 6.0ms preprocess, 444.0ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 440.9ms
# Speed: 6.0ms preprocess, 440.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 465.8ms
# Speed: 7.0ms preprocess, 465.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 468.9ms
# Speed: 7.0ms preprocess, 468.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 464.0ms
# Speed: 6.0ms preprocess, 464.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 471.1ms
# Speed: 6.0ms preprocess, 471.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 454.1ms
# Speed: 6.0ms preprocess, 454.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 454.7ms
# Speed: 8.0ms preprocess, 454.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 441.1ms
# Speed: 8.6ms preprocess, 441.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 441.4ms
# Speed: 8.0ms preprocess, 441.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 461.3ms
# Speed: 6.0ms preprocess, 461.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 423.7ms
# Speed: 8.0ms preprocess, 423.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 449.3ms
# Speed: 9.0ms preprocess, 449.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 453.3ms
# Speed: 7.0ms preprocess, 453.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 446.6ms
# Speed: 6.0ms preprocess, 446.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 429.4ms
# Speed: 9.0ms preprocess, 429.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 447.3ms
# Speed: 6.3ms preprocess, 447.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 454.5ms
# Speed: 6.3ms preprocess, 454.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 437.8ms
# Speed: 10.0ms preprocess, 437.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 456.6ms
# Speed: 6.0ms preprocess, 456.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 430.9ms
# Speed: 8.0ms preprocess, 430.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 427.3ms
# Speed: 5.2ms preprocess, 427.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 458.8ms
# Speed: 9.0ms preprocess, 458.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 439.1ms
# Speed: 6.0ms preprocess, 439.1ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 449.9ms
# Speed: 10.2ms preprocess, 449.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 450.3ms
# Speed: 6.0ms preprocess, 450.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 463.3ms
# Speed: 6.0ms preprocess, 463.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 460.9ms
# Speed: 8.3ms preprocess, 460.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 455.8ms
# Speed: 6.0ms preprocess, 455.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 442.1ms
# Speed: 7.0ms preprocess, 442.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 425.8ms
# Speed: 7.0ms preprocess, 425.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 441.9ms
# Speed: 6.0ms preprocess, 441.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 444.4ms
# Speed: 5.7ms preprocess, 444.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 443.7ms
# Speed: 7.0ms preprocess, 443.7ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 466.3ms
# Speed: 7.0ms preprocess, 466.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 417.3ms
# Speed: 6.0ms preprocess, 417.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 434.9ms
# Speed: 8.1ms preprocess, 434.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 445.9ms
# Speed: 6.0ms preprocess, 445.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 1 truck, 434.8ms
# Speed: 6.0ms preprocess, 434.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 432.0ms
# Speed: 8.0ms preprocess, 432.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 444.0ms
# Speed: 9.0ms preprocess, 444.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 442.8ms
# Speed: 10.0ms preprocess, 442.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 439.4ms
# Speed: 6.0ms preprocess, 439.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 434.4ms
# Speed: 8.0ms preprocess, 434.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 419.9ms
# Speed: 6.0ms preprocess, 419.9ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 436.5ms
# Speed: 8.0ms preprocess, 436.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 441.9ms
# Speed: 8.0ms preprocess, 441.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 452.7ms
# Speed: 8.0ms preprocess, 452.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 451.7ms
# Speed: 8.0ms preprocess, 451.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 445.3ms
# Speed: 7.0ms preprocess, 445.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 448.8ms
# Speed: 6.0ms preprocess, 448.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 468.2ms
# Speed: 6.0ms preprocess, 468.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 435.4ms
# Speed: 8.0ms preprocess, 435.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 439.6ms
# Speed: 11.0ms preprocess, 439.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 462.4ms
# Speed: 8.0ms preprocess, 462.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 446.3ms
# Speed: 7.0ms preprocess, 446.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 427.5ms
# Speed: 6.0ms preprocess, 427.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 443.9ms
# Speed: 9.0ms preprocess, 443.9ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 437.8ms
# Speed: 6.0ms preprocess, 437.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 424.9ms
# Speed: 7.0ms preprocess, 424.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 457.2ms
# Speed: 9.0ms preprocess, 457.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 449.0ms
# Speed: 9.0ms preprocess, 449.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 442.4ms
# Speed: 6.0ms preprocess, 442.4ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 456.0ms
# Speed: 5.9ms preprocess, 456.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 454.0ms
# Speed: 7.0ms preprocess, 454.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 457.5ms
# Speed: 5.0ms preprocess, 457.5ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 439.2ms
# Speed: 10.0ms preprocess, 439.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 460.0ms
# Speed: 6.0ms preprocess, 460.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 466.7ms
# Speed: 9.0ms preprocess, 466.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 457.4ms
# Speed: 6.0ms preprocess, 457.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 439.8ms
# Speed: 6.0ms preprocess, 439.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 train, 443.3ms
# Speed: 9.0ms preprocess, 443.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 train, 456.8ms
# Speed: 9.0ms preprocess, 456.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 451.3ms
# Speed: 7.0ms preprocess, 451.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 448.3ms
# Speed: 7.0ms preprocess, 448.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 459.7ms
# Speed: 5.0ms preprocess, 459.7ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 469.7ms
# Speed: 6.0ms preprocess, 469.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 trucks, 464.8ms
# Speed: 8.0ms preprocess, 464.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 trucks, 477.5ms
# Speed: 9.0ms preprocess, 477.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 453.8ms
# Speed: 8.0ms preprocess, 453.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 trucks, 449.3ms
# Speed: 6.7ms preprocess, 449.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 trucks, 447.8ms
# Speed: 10.6ms preprocess, 447.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 trucks, 444.5ms
# Speed: 6.8ms preprocess, 444.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 trucks, 455.8ms
# Speed: 6.0ms preprocess, 455.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 461.0ms
# Speed: 8.0ms preprocess, 461.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 437.3ms
# Speed: 7.0ms preprocess, 437.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 460.8ms
# Speed: 9.0ms preprocess, 460.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 431.1ms
# Speed: 11.0ms preprocess, 431.1ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 460.8ms
# Speed: 7.0ms preprocess, 460.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 449.0ms
# Speed: 6.0ms preprocess, 449.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 433.9ms
# Speed: 9.0ms preprocess, 433.9ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 446.3ms
# Speed: 5.0ms preprocess, 446.3ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 439.9ms
# Speed: 6.0ms preprocess, 439.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 445.6ms
# Speed: 8.0ms preprocess, 445.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 459.4ms
# Speed: 7.0ms preprocess, 459.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 448.6ms
# Speed: 7.0ms preprocess, 448.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 470.3ms
# Speed: 6.0ms preprocess, 470.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 453.7ms
# Speed: 11.0ms preprocess, 453.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 445.5ms
# Speed: 7.0ms preprocess, 445.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 461.4ms
# Speed: 5.0ms preprocess, 461.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 457.8ms
# Speed: 6.0ms preprocess, 457.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 440.1ms
# Speed: 7.0ms preprocess, 440.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 443.7ms
# Speed: 6.9ms preprocess, 443.7ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 448.3ms
# Speed: 6.0ms preprocess, 448.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 458.4ms
# Speed: 7.0ms preprocess, 458.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 459.6ms
# Speed: 9.0ms preprocess, 459.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 462.3ms
# Speed: 6.8ms preprocess, 462.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 444.8ms
# Speed: 7.0ms preprocess, 444.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 439.8ms
# Speed: 6.0ms preprocess, 439.8ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 442.8ms
# Speed: 8.0ms preprocess, 442.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 451.5ms
# Speed: 8.0ms preprocess, 451.5ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 442.3ms
# Speed: 8.0ms preprocess, 442.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 451.5ms
# Speed: 8.0ms preprocess, 451.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 447.1ms
# Speed: 8.2ms preprocess, 447.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 466.1ms
# Speed: 9.0ms preprocess, 466.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 454.3ms
# Speed: 7.0ms preprocess, 454.3ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 462.2ms
# Speed: 6.6ms preprocess, 462.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 455.9ms
# Speed: 8.0ms preprocess, 455.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 450.9ms
# Speed: 7.9ms preprocess, 450.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 444.3ms
# Speed: 10.0ms preprocess, 444.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 453.3ms
# Speed: 6.0ms preprocess, 453.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 436.7ms
# Speed: 7.0ms preprocess, 436.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 433.8ms
# Speed: 7.0ms preprocess, 433.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 459.8ms
# Speed: 6.0ms preprocess, 459.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 460.6ms
# Speed: 6.0ms preprocess, 460.6ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 459.3ms
# Speed: 7.0ms preprocess, 459.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 448.9ms
# Speed: 6.0ms preprocess, 448.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 437.0ms
# Speed: 9.0ms preprocess, 437.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 429.4ms
# Speed: 7.0ms preprocess, 429.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 454.3ms
# Speed: 5.0ms preprocess, 454.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 446.4ms
# Speed: 7.0ms preprocess, 446.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 427.0ms
# Speed: 8.0ms preprocess, 427.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 449.6ms
# Speed: 6.0ms preprocess, 449.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 434.8ms
# Speed: 7.0ms preprocess, 434.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 445.4ms
# Speed: 8.6ms preprocess, 445.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 471.6ms
# Speed: 7.0ms preprocess, 471.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 453.8ms
# Speed: 11.0ms preprocess, 453.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 458.8ms
# Speed: 8.0ms preprocess, 458.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 433.8ms
# Speed: 7.0ms preprocess, 433.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 453.6ms
# Speed: 8.9ms preprocess, 453.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 451.2ms
# Speed: 9.0ms preprocess, 451.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 463.7ms
# Speed: 8.0ms preprocess, 463.7ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 445.1ms
# Speed: 8.0ms preprocess, 445.1ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 447.0ms
# Speed: 7.0ms preprocess, 447.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 437.5ms
# Speed: 6.0ms preprocess, 437.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 460.3ms
# Speed: 7.0ms preprocess, 460.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 469.0ms
# Speed: 7.0ms preprocess, 469.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 440.8ms
# Speed: 6.0ms preprocess, 440.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 445.9ms
# Speed: 8.0ms preprocess, 445.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 461.7ms
# Speed: 7.0ms preprocess, 461.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 441.0ms
# Speed: 6.0ms preprocess, 441.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 455.3ms
# Speed: 10.0ms preprocess, 455.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 449.2ms
# Speed: 8.1ms preprocess, 449.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 446.8ms
# Speed: 9.0ms preprocess, 446.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 456.8ms
# Speed: 6.0ms preprocess, 456.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 464.3ms
# Speed: 6.0ms preprocess, 464.3ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 460.5ms
# Speed: 7.0ms preprocess, 460.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 453.4ms
# Speed: 8.0ms preprocess, 453.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 444.9ms
# Speed: 7.0ms preprocess, 444.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 446.4ms
# Speed: 9.0ms preprocess, 446.4ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 452.8ms
# Speed: 6.8ms preprocess, 452.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 455.9ms
# Speed: 6.0ms preprocess, 455.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 442.3ms
# Speed: 8.0ms preprocess, 442.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 438.6ms
# Speed: 9.0ms preprocess, 438.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 429.4ms
# Speed: 8.0ms preprocess, 429.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 442.8ms
# Speed: 8.0ms preprocess, 442.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 445.8ms
# Speed: 6.0ms preprocess, 445.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 459.9ms
# Speed: 9.0ms preprocess, 459.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 429.8ms
# Speed: 9.0ms preprocess, 429.8ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 450.8ms
# Speed: 8.0ms preprocess, 450.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 448.8ms
# Speed: 7.0ms preprocess, 448.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 443.9ms
# Speed: 6.0ms preprocess, 443.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 428.9ms
# Speed: 8.4ms preprocess, 428.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 441.1ms
# Speed: 6.0ms preprocess, 441.1ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 460.8ms
# Speed: 9.0ms preprocess, 460.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 461.8ms
# Speed: 6.0ms preprocess, 461.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 415.0ms
# Speed: 6.0ms preprocess, 415.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 439.7ms
# Speed: 5.6ms preprocess, 439.7ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 467.0ms
# Speed: 8.3ms preprocess, 467.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 452.5ms
# Speed: 6.0ms preprocess, 452.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 455.5ms
# Speed: 7.0ms preprocess, 455.5ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 441.8ms
# Speed: 6.0ms preprocess, 441.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 452.1ms
# Speed: 7.0ms preprocess, 452.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 454.1ms
# Speed: 9.0ms preprocess, 454.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 truck, 448.8ms
# Speed: 11.0ms preprocess, 448.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 445.1ms
# Speed: 8.0ms preprocess, 445.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 458.8ms
# Speed: 8.0ms preprocess, 458.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 455.3ms
# Speed: 8.0ms preprocess, 455.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 440.1ms
# Speed: 5.0ms preprocess, 440.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 425.5ms
# Speed: 12.0ms preprocess, 425.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 442.3ms
# Speed: 8.0ms preprocess, 442.3ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 449.3ms
# Speed: 8.0ms preprocess, 449.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 465.3ms
# Speed: 8.0ms preprocess, 465.3ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 446.0ms
# Speed: 6.2ms preprocess, 446.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 437.0ms
# Speed: 7.0ms preprocess, 437.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 truck, 447.6ms
# Speed: 6.0ms preprocess, 447.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicle Entry Counts: {'bicycle': 0, 'car': 11, 'motorcycle': 0, 'bus': 0, 'truck': 1}
# Vehicle Exit Counts: {'bicycle': 0, 'car': 1, 'motorcycle': 0, 'bus': 1, 'truck': 3}

# %% [markdown]
# ## Dynmaic vehicle counter

# %%
from ultralytics import YOLO
import cv2, time

def run_yolov8_generalized_counter(video_source, model_path, counting_lines):
    """
    Run vehicle detection, tracking, and counting using YOLOv8 with generalized counting lines.
    Args:
        video_source: Path to the video file or webcam index (e.g., 0 for default webcam).
        model_path: Path to YOLOv8 model (e.g., "yolov8n.pt").
        counting_lines: List of counting line configurations (e.g., entry/exit lines).
    """
    # Load YOLOv8 model
    model = YOLO(model_path)

    # Open the video source
    cap = cv2.VideoCapture(video_source)
    if not cap.isOpened():
        print('Error: Unable to open video source.')
        return

    # Get original video resolution
    original_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    original_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    print(f"Original video resolution: {original_width}x{original_height}")

    # YOLOv8 resolution
    yolo_width, yolo_height = 640, 384  # From YOLOv8 logs

    # Scale counting lines to YOLOv8 resolution
    scaled_lines = []
    for line in counting_lines:
        scaled_line = {
            "label": line["label"],
            "x1": int(line["x1"] * yolo_width / original_width),
            "y1": int(line["y1"] * yolo_height / original_height),
            "x2": int(line["x2"] * yolo_width / original_width),
            "y2": int(line["y2"] * yolo_height / original_height),
            "offset": int(line["offset"] * yolo_height / original_height),
        }
        scaled_lines.append(scaled_line)
    print(f"Scaled lines: {scaled_lines}")

    # Vehicle counters and helper variables
    class_names = model.names
    vehicle_class_ids = [1, 2, 3, 5, 7]  # IDs for bicycle, car, motorcycle, bus, truck
    counters = {line["label"]: {class_names[cls]: 0 for cls in vehicle_class_ids} for line in scaled_lines}
    tracked_ids = {line["label"]: [] for line in scaled_lines}  # Track IDs for each line

    while True:
        ret, frame = cap.read()
        if not ret:
            break  # Exit the loop if no more frames

        start_time = time.time()  # Start timer for FPS calculation

        # Resize frame to YOLOv8's input resolution
        resized_frame = cv2.resize(frame, (yolo_width, yolo_height))

        # Perform detection and tracking
        results = model.track(resized_frame, persist=True, tracker="bytetrack.yaml")  # Use built-in ByteTrack tracker

        if results and results[0].boxes is not None:
            for box in results[0].boxes:
                x1, y1, x2, y2 = map(int, box.xyxy.cpu().numpy().flatten())  # Bounding box coordinates
                cls = int(box.cls.cpu().numpy().item())  # Class ID
                track_id = int(box.id.cpu().numpy().item()) if box.id is not None else None
                conf = box.conf.numpy().item()
                
                # Calculate the center of the bounding box
                center_x, center_y = (x1 + x2) // 2, (y1 + y2) // 2

                # Check crossing for each scaled line
                for line in scaled_lines:
                    label, lx1, ly1, lx2, ly2, offset = line.values()
                    if lx1 <= center_x <= lx2 and ly1 - offset <= center_y <= ly1 + offset:
                        if track_id not in tracked_ids[label] and cls in vehicle_class_ids:
                            counters[label][class_names[cls]] += 1
                            tracked_ids[label].append(track_id)

                # Draw bounding box
                color = (0, 255, 0)
                cv2.rectangle(resized_frame, (x1, y1), (x2, y2), color, 1)
                #label = f"ID: {track_id}, Class: {class_names[cls]}, Conf: {conf:.2f}"
                label = class_names[cls]
                cv2.putText(resized_frame, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 1)

        # Draw scaled lines
        for idx, line in enumerate(scaled_lines):
            label, lx1, ly1, lx2, ly2, offset = line.values()

            # Draw the counting line
            cv2.line(resized_frame, (lx1, ly1), (lx2, ly2), (0, 127, 255), 3)

        # Draw vertical counters for each line
        x_start = 30  # Starting x position for the first column
        x_offset = 200  # Horizontal distance between columns
        y_start = 30  # Starting y position for rows
        y_offset = 30  # Vertical spacing between rows

        for col_idx, line in enumerate(scaled_lines):
            label = line["label"]
            x_pos = x_start + col_idx * x_offset  # Calculate column position for this line

            # Display the line label (e.g., "Entry1 Counts")
            cv2.putText(
                resized_frame, 
                f"{label} Counts:", 
                (x_pos, y_start), 
                cv2.FONT_HERSHEY_SIMPLEX, 
                0.5,  # Font scale
                (255, 255, 255),  # White color
                1  # Thickness
            )

            # Display each class count in a vertical list
            for row_idx, (cls_name, count) in enumerate(counters[label].items()):
                y_pos = y_start + (row_idx + 1) * y_offset  # Calculate row position
                cv2.putText(
                    resized_frame, 
                    f"{cls_name}: {count}", 
                    (x_pos, y_pos), 
                    cv2.FONT_HERSHEY_SIMPLEX, 
                    0.5,  # Font scale
                    (255, 255, 255),  # White color
                    1  # Thickness
                )

        # Display FPS
        fps = 1 / (time.time() - start_time)
        fps_text = f"FPS: {fps:.2f}"
        cv2.putText(resized_frame, fps_text, (20, 40), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)

        # Resize for display only
        display_frame = cv2.resize(resized_frame, (original_width, original_height))  # Scale back for visualization
        cv2.imshow("YOLOv8 Vehicle Tracking", cv2.resize (display_frame, (960, 540)))
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break

    cap.release()
    cv2.destroyAllWindows()
    for label, counts in counters.items():
        print(f"{label} Counts:", counts)

# %% [markdown]
# ### Testing our Dynamic counter
# #### creating a function to get the coordnates (x,y)

# %%
import cv2

def get_coordinates(event, x, y, flags, param):
    if event == cv2.EVENT_LBUTTONDOWN:  # Left mouse button click
        print(f"Selected point: ({x}, {y})")

cap = cv2.VideoCapture('./highway2.mp4')
count = 0
while count < 6:
    ret, frame = cap.read()
    if ret:
        cv2.imshow("Frame", cv2.resize (frame, (960, 540)))
    if count == 3:
        cv2.setMouseCallback("Frame", get_coordinates)  # Attach the callback
        cv2.waitKey(0)  # Wait for user to click
    count +=1
cap.release()
cv2.destroyAllWindows()

# %%
counting_lines = [
    {"label": "Entry1", "x1": 469, "y1": 397, "x2": 814, "y2": 449, "offset": 20},
    {"label": "Entry2", "x1": 1037, "y1": 424, "x2": 1431, "y2": 346, "offset": 20}
]

# %%
run_yolov8_generalized_counter("videos/highway3.mp4", "model/yolov8s.pt", counting_lines)
# Out:
# Original video resolution: 1920x1080
# Scaled lines: [{'label': 'Entry1', 'x1': 156, 'y1': 141, 'x2': 271, 'y2': 159, 'offset': 7}, {'label': 'Entry2', 'x1': 345, 'y1': 150, 'x2': 477, 'y2': 123, 'offset': 7}]
#
# 0: 384x640 2 cars, 1 train, 864.5ms
# Speed: 9.0ms preprocess, 864.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1196.3ms
# Speed: 77.8ms preprocess, 1196.3ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 train, 750.1ms
# Speed: 5.8ms preprocess, 750.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 train, 412.7ms
# Speed: 8.0ms preprocess, 412.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 train, 426.9ms
# Speed: 4.0ms preprocess, 426.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 512.2ms
# Speed: 5.0ms preprocess, 512.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 453.0ms
# Speed: 4.0ms preprocess, 453.0ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 465.3ms
# Speed: 4.0ms preprocess, 465.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Entry1 Counts: {'bicycle': 0, 'car': 0, 'motorcycle': 0, 'bus': 0, 'truck': 0}
# Entry2 Counts: {'bicycle': 0, 'car': 0, 'motorcycle': 0, 'bus': 0, 'truck': 0}
